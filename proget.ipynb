# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://kino.mail.ru/cinema/total/'
response = requests.get(url)

# %%
data = BeautifulSoup(response.text , 'lxml')

# %%
print(data)
# Out:
# <!DOCTYPE html>
# ...

# %%
film_data = data.find('div', class_= 'cols__column cols__column_small_percent-100 cols__column_medium_percent-50 cols__column_large_percent-50')

# %%
film_data
# Out:
# <div class="cols__column cols__column_small_percent-100 cols__column_medium_percent-50 cols__column_large_percent-50"><div class="cols__inner"><div class="js-track_visibility" data-counter="8555618"></div><div class="p-itemevent-small js-event margin_bottom_30" data-id="709388" data-logger="ListItem"><div class="p-poster p-poster_left p-poster_normal p-poster_fixed margin_bottom_5"><div class="p-framer p-framer_poster p-framer_poster_normal p-framer_fixed align_left"><picture class="picture js-itemevent_poster p-framer__picture"><source class="" srcset="https://resizer.mail.ru/p/25e85ca5-28f1-5cd6-81e4-4bcc06c86650/AAACxOp4dxuL4qDb4qyuPfPbO8izA4u5dKncEpdotANbvNLm4G6QzddwvgFkv74YaiyNpS_orAP0xxghrLCdl7G4aks.webp 1x, https://resizer.mail.ru/p/25e85ca5-28f1-5cd6-81e4-4bcc06c86650/dpr:200/AAACxOp4dxuL4qDb4qyuPfPbO8izA4u5dKncEpdotANbvNLm4G6QzddwvgFkv74YaiyNpS_orAP0xxghrLCdl7G4aks.webp 2x" type="image/webp"/><img alt="" class="picture__image picture__image_cover" height="165" src="https://r
# ...

# %%
# <div class="cols__column cols__column_small_percent-100 cols__column_medium_percent-50 cols__column_large_percent-50">
# <div class="cols__inner">
# <div class="js-track_visibility" data-counter="8555618">
# </div>
# <div class="p-itemevent-small js-event margin_bottom_30" data-id="709388" data-logger="ListItem">
# <div class="p-poster p-poster_left p-poster_normal p-poster_fixed margin_bottom_5">
# <div class="p-framer p-framer_poster p-framer_poster_normal p-framer_fixed align_left">
# <picture class="picture js-itemevent_poster p-framer__picture">
# <source class="" srcset="https://resizer.mail.ru/p/25e85ca5-28f1-5cd6-81e4-4bcc06c86650/AAACxOp4dxuL4qDb4qyuPfPbO8izA4u5dKncEpdotANbvNLm4G6QzddwvgFkv74YaiyNpS_orAP0xxghrLCdl7G4aks.webp 1x, https://resizer.mail.ru/p/25e85ca5-28f1-5cd6-81e4-4bcc06c86650/dpr:200/AAACxOp4dxuL4qDb4qyuPfPbO8izA4u5dKncEpdotANbvNLm4G6QzddwvgFkv74YaiyNpS_orAP0xxghrLCdl7G4aks.webp 2x" type="image/webp"/><img alt="" class="picture__image picture__image_cover" height="165" src="https://resizer.mail.ru/p/25e85ca5-28f1-5cd6-81e4-4bcc06c86650/AAACxOp4dxuL4qDb4qyuPfPbO8izA4u5dKncEpdotANbvNLm4G6QzddwvgFkv74YaiyNpS_orAP0xxghrLCdl7G4aks.jpg" srcset="https://resizer.mail.ru/p/25e85ca5-28f1-5cd6-81e4-4bcc06c86650/dpr:200/AAACxOp4dxuL4qDb4qyuPfPbO8izA4u5dKncEpdotANbvNLm4G6QzddwvgFkv74YaiyNpS_orAP0xxghrLCdl7G4aks.jpg 2x" title="" width="110"/>
# </picture></div></div><div class="p-itemevent-small__info"><span class="text text_block text_fixed text_light_large">
# <a class="link link_inline link-holder link-holder_itemevent link-holder_itemevent_small" href="/cinema/movies/709388_1_1/">
# <span class="link__text">1+1</span></a></span><span class="text text_block text_fixed text_light_small color_gray margin_bottom_5">Intouchables</span>
# <div class="margin_top_5">
# <a class="p_link_black" href="/cinema/total/fra/">Франция</a>, <a class="p_link_black" href="/cinema/total/2011/">2011</a>,
# <a class="p_link_black" href="/cinema/total/drama/">драма</a>, 
# <a class="p_link_black" href="/cinema/total/komedija/">комедия</a>,
# <a class="p_link_black" href="/cinema/total/biografija/">биография</a>
# </div></div><div class="p-itemevent-small__info"><button class="button button_watch js-event__button-favorite margin_top_10 margin_right_10 valign_top" data-id="709388"><svg class="loader loader_button button__loader" version="1.1" viewbox="-10 -10 220 220" xmlns="http://www.w3.org/2000/svg"><defs><lineargradient gradientunits="objectBoundingBox" id="transparent" x1="0" x2="0" y1="0" y2="1"><stop offset="0%" stop-color="rgba(234, 255, 0, 0)" stop-opacity="0"></stop><stop offset="100%" stop-color="rgba(234, 255, 0, 0)" stop-opacity="0"></stop></lineargradient><lineargradient gradientunits="objectBoundingBox" id="one" x1="1" x2="0" y1="0" y2="1"><stop offset="0%" stop-color="rgba(234, 255, 0, 0)" stop-opacity="0"></stop><stop offset="100%" stop-color="rgba(234, 255, 0, .33)"></stop></lineargradient><lineargradient gradientunits="objectBoundingBox" id="two" x1="1" x2="0" y1="1" y2="0"><stop offset="0%" stop-color="rgba(234, 255, 0, .33)"></stop><stop offset="100%" stop-color="rgba(234, 255, 0, .66)"></stop></lineargradient><lineargradient gradientunits="objectBoundingBox" id="three" x1="0" x2="0" y1="1" y2="0"><stop offset="0%" stop-color="rgba(234, 255, 0, .66)"></stop><stop offset="100%" stop-color="rgba(234, 255, 0, 1)"></stop></lineargradient><lineargradient gradientunits="objectBoundingBox" id="four" x1="0" x2="1" y1="1" y2="0"><stop offset="0%" stop-color="rgba(234, 255, 0, 1)"></stop><stop offset="100%" stop-color="rgba(234, 255, 0, 1)"></stop></lineargradient><lineargradient gradientunits="objectBoundingBox" id="five" x1="0" x2="1" y1="0" y2="1"><stop offset="0%" stop-color="rgba(234, 255, 0, 1)"></stop><stop offset="100%" stop-color="rgba(234, 255, 0, 1)"></stop></lineargradient></defs><g fill="none" stroke-width="40" transform="translate(100,100)">
# <path d="M 81.6,-40 A 90,90 0 0,1 81.6,40" stroke="url(#transparent)"></path><path d="M 81.6,40 A 90,90 0 0,1 0,90" stroke="url(#one)"></path><path d="M 0,90 A 90,90 0 0,1 -81.6,40" stroke="url(#two)"></path><path d="M -81.6,40 A 90,90 0 0,1 -81.6,-40" stroke="url(#three)"></path><path d="M -81.6,-40 A 90,90 0 0,1 0,-90" stroke="url(#four)"></path><path d="M 0,-90 A 90,90 0 0,1 81.6,-40" stroke="url(#five)" stroke-linecap="round"></path></g></svg><span class="button__inner"><svg class="icon icon_fill_current icon_svg icon_media-ui button__icon button__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_favorite-on"></use></svg></span></button><a class="button button_color_project margin_top_10 js-track_visibility" data-counter="137560668" href="/cinema/movies/709388_1_1/#watch" name="clb137560668"><span class="button__inner"><svg class="icon icon_fill_current icon_svg icon_media-ui button__icon button__icon_left" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_play-round"></use></svg><div class="button__text">Смотреть за 1 р.</div></span></a></div><div class="clearin"></div><div class="p-rates p-rates_tiny margin_top_10 js-module" data-module="RatingView"><div class="p-rates__inner"><div class="p-rates__item p-rates__item_rating"><div class="p-rate-flag p-rate-flag_medium margin_right_5"><div class="p-rate-flag__inner"><svg class="icon icon_media-ui icon_indent_top-n1 icon_fill_current icon_svg icon_media-ui margin_right_5" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg><span class="p-rate-flag__text">8.4</span></div><div class="p-rate-flag__imdb-inner p-rate-flag__imdb-inner_left"><span class="p-rate-flag__imdb-title">IMDb</span><span class="p-rate-flag__imdb-text">8.5</span></div></div></div><div class="p-rates__item p-rates__item_rater"><div class="p-rates__rater js-rating__container js-track_click" data-entity-id="709388" data-entity-type="event" data-params="Оценка,1+1" data-rating-type="rate"><div class="p-rates__rater-title">Оценить</div><div class="p-rates__rater-action"><div class="p-rates__rater-stars"><div class="p-rating p-rating_small p-rating_hidden-value js-track_click" data-params="Оценка,1+1"><div class="p-rating__item js-rating__star" data-mark="1" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="2" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="3" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="4" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="5" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="6" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="7" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="8" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="9" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div><div class="p-rating__item js-rating__star" data-mark="10" name=""><svg class="icon icon_media-ui icon_fill_current icon_svg icon_media-ui p-rating__icon" height="18" width="18"><use class="icon__use" xlink:href="/-/35cf95fd/bem/web/web.bundles/common/common.svg#icon_actions_rating"></use></svg></div></div></div><div class="p-rates__rater-value"><span class="p-rates__rater-number js-rating__value">0</span></div></div><div class="p-rates__rater-count">105463 уже оценили</div></div></div></div></div></div></div></div>

# %%
film_data.div.a.span.text
# Out:
# '1+1'

# %%
import pandas as pd
import numpy as np

# %%
random_digits = np.random.choice(13, size=5, replace=False)
random_digits
# Out:
# array([7, 3, 4, 1, 0])

# %%
df = pd.read_csv('/home/valera/ds_bootcamp/ds-phase-2/11-nn-ext/progect/movies.csv')
df
# Out:
#                                              page_url  \
# 0      https://kinogo.uk/9073-deva-i-drakon-2024.html
# 1    https://kinogo.uk/6640-kung-fu-panda-4-2024.html
# 2            https://kinogo.uk/5783-djuna-2-2023.html
# 3   https://kinogo.uk/6185-avatar-poslednij-mag-vo...
# 4    https://kinogo.uk/9474-territorija-zla-2024.html
# 5           https://kinogo.uk/9349-pustoshi-2024.html
# 6             https://kinogo.uk/8861-dogmen-2023.html
# 7   https://kinogo.uk/8862-vozdushnoe-ograblenie-2...
# 8          https://kinogo.uk/6511-pchelovod-2024.html
# 9   https://kinogo.uk/6178-mjatezhnaja-luna-2023.html
# 10  https://kinogo.uk/6450-akvamen-2-poterjannoe-c...
# 11     https://kinogo.uk/8377-semejnyj-plan-2023.html
#
#                                               img_url  \
# 0   kinogo.uk//uploads/mini/full/8a/afd93f08b408c6...
# 1   kinogo.uk//uploads/mini/full/2c/cb318f7d5965d5...
# 2   kinogo.uk//uploads/mini/full/39/269a87642056f7...
# ...

# %%
df['genres'].iloc[3] == 'NaN'
# Out:
# False

# %%
df['kinopoisk'][3] == 0
# Out:
# True
